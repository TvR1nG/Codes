# %%
import ipywidgets as widgets	# 控件库
from IPython.display import display	# 显示控件的方法

text = widgets.Text()
display(text)

def print_value(sender):
    print(sender.value)

text.on_submit(print_value)	# 回车以提交内容
# Out:
# Text(value='')
# r
# go

# %%
#coding=utf-8
test=input(u"input:")

if test == "caonima":
  print('yes')
# Out:
# input:caonima
# yes

# %%
import pandas as pd
import numpy as np
s=pd.Series(np.random.randn(100).cumsum(), index=np.arange(0, 100))
s.plot()

# %%
df = pd.DataFrame({
   'mAP': [0.331,0.381,0.445,0.492,0.541,0.562,0.564,0.567,0.612,0.613,0.615]
   }, index=[0,5,10,15,20,25,30,35,40,45,50])
lines = df.plot.line()
